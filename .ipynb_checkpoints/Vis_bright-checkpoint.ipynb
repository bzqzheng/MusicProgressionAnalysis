# %%
import pandas
pandas.set_option('display.max_rows',1000)
pandas.set_option('display.max_columns',10000)
import math
import matplotlib
import matplotlib.pyplot as plt

# %%
def clean_dict_func(input_dict):
    return dict((k, v) for k, v in input_dict.items() if not (type(k) == float and math.isnan(k)))

def get_year_dict(int_year):
    file_name = 'music'+str(int_year)+'_chords.csv'
    df = pandas.read_csv(file_name)
    df = df.drop(df.columns[0], axis=1)
    index = 0
    temp_dict = dict()
    for index in range(0, len(df)):
        row = df.iloc[index]
        top1 = row['top_1']
        top2 = row['top_2']
        top3 = row['top_3']
        if top1 in temp_dict:
            temp_dict[top1] = temp_dict[top1] + (1000 - index*10)
        else:
            temp_dict[top1] = 1000 - index*10
        if top2 in temp_dict:
            temp_dict[top2] = temp_dict[top2] + (1000 - index*10) - 2
        else:
            temp_dict[top2] = 1000 - index*10 - 2
        if top3 in temp_dict:
            temp_dict[top3] = temp_dict[top3] + (1000 - index*10) - 3
        else:
            temp_dict[top3] = 1000 - index*10 - 3
    clean_dict = clean_dict_func(temp_dict)
    temp_df = pandas.DataFrame()
    temp_df = temp_df.from_dict(clean_dict, orient='index')
    temp_col_name = 'year_'+str(int_year)
    temp_df.columns = [temp_col_name]
    temp_df = temp_df.sort_values(temp_col_name, ascending=False)
    return temp_df

# %%
final_df = get_year_dict(2006)

# %%
for i in range(2007, 2017):
    final_df = final_df.join(get_year_dict(i))

# %%
final_df = final_df.fillna(0)

# %%
final_df['chord_pair'] = final_df.index

# %%
ax = pandas.tools.plotting.parallel_coordinates(final_df, 'chord_pair')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)
ax.figure.set_size_inches(15, 6)
plt.show()

# %%
# %matplotlib inline
final_trans = final_df.transpose()
final_trans = final_trans.drop(final_trans.index[len(final_trans)-1])

# %%
pp = final_trans.plot(xticks=range(len(final_trans.index))) # xticks=range(len(final_trans.index))
leg = pp.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)
pp.figure.set_size_inches(15, 6)

# %%
final_df['year_2011'].max()
# Out:
# 9709.0

# %%
final_df['year_2011']
# Out:
# Em C                    3570.0
# D A                     1397.0
# G D                     9709.0
# C G                     4576.0
# G C                     3775.0
# Bb F                    1424.0
# D Em                    3222.0
# F C                     2747.0
# C D                     1600.0
# A Bm                     960.0
# E B                      347.0
# Em Bm                      0.0
# F G                     1624.0
# G F                      978.0
# F Dm                     517.0
# G Am                    1394.0
# Em D                    4286.0
# Am F                    2298.0
# Am G                    1586.0
# G Dm                     617.0
# A E                      954.0
# G Em                     867.0
# G E                      358.0
# Am D                       0.0
# Am Em                    570.0
# A Em                    1591.0
# F Bb                       0.0
# D E                        0.0
# G G/F#                     0.0
# G/F# Em7                   0.0
# Em7 Cadd9                827.0
# Em F                     888.0
# Bm: C:                     0.0
# Dsus2: Em:                 0.0
# Cadd9: D:                  0.0
# E A                        0.0
# Am C                     580.0
# Esus E                     0.0
# Ab A                       0.0
# A Ab                       0.0
# A A#                       0.0
# Am D#dim                   0.0
# D#dim Em                   0.0
# C Bm                       0.0
# C A7                       0.0
# Dm G                     940.0
# D C                     2354.0
# Em D*                      0.0
# A Dm                       0.0
# Dm A                       0.0
# C#m A                      0.0
# D5 A5                      0.0
# A5 D5                      0.0
# F#5 A5                     0.0
# Dm F                       0.0
# Em E                       0.0
# D F#                       0.0
# F# Bm                      0.0
# G Dsus4                    0.0
# D#m Em                     0.0
# D/F# C                     0.0
# F E                        0.0
# C F                     2972.0
# E/G# D                     0.0
# A E/G#                     0.0
# Asus4, Bm,                 0.0
# Bm, G,                     0.0
# G... Asus4,                0.0
# D, C.                      0.0
# G, D,                      0.0
# Em, G,                     0.0
# C7 B7                      0.0
# B7 A7                      0.0
# A7 E7                      0.0
# B C#                       0.0
# F# E                       0.0
# A C                      817.0
# Em D/F                     0.0
# B7 Cadd9                   0.0
# D/F G                      0.0
# DM7 C#m                    0.0
# Bm E                       0.0
# D-F#m-Bm-A D               0.0
# F C-G-Am-F                 0.0
# F G)                       0.0
# AM F                       0.0
# Emaj7 Cmaj7                0.0
# Cmaj7 C#m7                 0.0
# C#m7 Am7                   0.0
# G Bb                       0.0
# Bm F#m                     0.0
# A C#m                      0.0
# E:022100 F#m:044222        0.0
# F#m:044222 Bm:004432       0.0
# D:000232 A/G               0.0
# Bb Gm                      0.0
# Eb Bb                    877.0
# Ab Eb                    878.0
# Dm Dm                      0.0
# A F                        0.0
# G A                     1247.0
# Dmaj Cmaj                  0.0
# D Dmaj                     0.0
# Dmaj7 Cmaj7                0.0
# Bm Am                      0.0
# G F#m                      0.0
# F#m G                    784.0
# D G                     2091.0
# C-Em-D C-Em-D              0.0
# C-G-Em-D C-G-Em-D          0.0
# Dm-C Bb                    0.0
# Bb G                       0.0
# G Eb                       0.0
# Eb G                       0.0
# E Bm                     650.0
# E F                        0.0
# A# F                       0.0
# Am7 D                      0.0
# C Am                       0.0
# Bm Cm                      0.0
# Bm C                     687.0
# D Am                       0.0
# Dm: Bm:                    0.0
# Am: F:                     0.0
# Gm G]                      0.0
# Em A                    1084.0
# Bm Em                      0.0
# C C                        0.0
# G# F                     418.0
# F G#                       0.0
# D Bb                       0.0
# D7 Gm7                     0.0
# Gm7 D#dim                  0.0
# Fmaj7 D7                   0.0
# G F*                       0.0
# F* C                       0.0
# G* F                       0.0
# B B                        0.0
# C Em                    3482.0
# A#m G#m                    0.0
# D#m A#m                    0.0
# Ab, Fm                     0.0
# Bm, A,                     0.0
# A, Em                      0.0
# Am7 G/D                    0.0
# E(5) D#(#5/b9)             0.0
# C#m7 B(11)                 0.0
# D#(#5/b9) F#7(11)          0.0
# Name: year_2011, dtype: float64
