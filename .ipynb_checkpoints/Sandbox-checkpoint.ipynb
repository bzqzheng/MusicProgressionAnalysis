# %%
import bs4
import requests

# %%
weekend = requests.get('https://www.ultimate-guitar.com/search.php?search_type=title&order=&value=I+feel+it+coming')
weekend_soup = bs4.BeautifulSoup(weekend.content, 'html.parser')

# %%
# Returns the Beautifulsoup of the input 'web_url'
def soup_page(web_url):
    req = requests.get(web_url)
    req_soup = bs4.BeautifulSoup(req.content, 'html.parser')
    return req_soup

# This function scrapes chords from a ultimate guitar website and
# returns a list of all the chords on that page
def get_chords(web_url):
    req_soup = soup_page(web_url)
    content = req_soup.find_all('pre', {'class':'js-tab-content'})
    chords_list = [word.replace('<span>', '').replace('</span>', '') for word in str(content).split() if word[0:6] == '<span>']
    return chords_list

# Returns the rating of a certain row in the ultimate guitar result page
def get_rating(row):
    temp_rate = row.find('td', {'class':'gray4 tresults--rating'})
    rate_list = temp_rate.find_all('b', {'class':'ratdig'})
    if (len(rate_list) > 0):
        rate = rate_list[0].text.strip()
        return float(rate)

# Returns the type of a certain row in a result page
def get_type(row):
    row_type = row.find_all('strong')[0].text.strip()
    return row_type

# Return the url of a certain row (version) of chords in a result page
def get_url(row):
    search_version = row.find_all('td',{'class':'search-version--td'})[0]
    href = search_version.find_all('a')[0].attrs['href']
    return href

# -- Puyush's functions --
def get_bbd_year_url(year_input):
    url = 'http://www.billboard.com/charts/year-end/'
    url += str(year_input)
    url += '/hot-100-songs'
    return url

def update_bbd_url(int_year):
    billboard = requests.get(get_bbd_year_url(int_year))
    billboard_soup = bs4.BeautifulSoup(billboard.content, 'html.parser')
    innerContent =  billboard_soup.find_all('div', {'data-content-type': 'yearEndChart'})
    artistData = innerContent[0].find_all('div' , {'class': 'ye-chart__layout-row'})
    artistData = artistData[1:]
    return artistData

def data(row):
    p = list()
    article = row.find_all('article', {'id': 'chart'})
    for i in range(len(article)):
        article_chart = article[i].find_all('div', {'class': 'ye-chart__item-primary'})
        songTitle = article_chart[0].find_all('h1', {'class':'ye-chart__item-title'})[0].text.strip()
        artistName = article_chart[0].find_all('h2', {'class':'ye-chart__item-subtitle'})[0].text.strip()
        p.append((artistName, songTitle))
    return p
# -- End of Puyush's functions --

def get_top100(int_year):
    pairs = list()
    top100Songs = list()
    pairs = [data(d) for d in update_bbd_url(int_year)]
    for p in pairs:
        top100Songs += p
    return top100Songs

def get_top100_query(int_year):
    top100 = get_top100(int_year)
    result = [clean_name(pair[1])+' '+clean_name(pair[0]) for pair in top100]
    return result

def clean_name(str_input):
    return str_input.lower().replace('(','').replace(')','').replace('featuring','').replace('&','')

def search_url(str_query):
    root = 'https://www.ultimate-guitar.com/search.php?search_type=title&order=&value='
    str_query = str_query.replace(' ', '+')
    return root+str_query

# %%
hello = 'https://www.ultimate-guitar.com/search.php?search_type=title&order=&value=hello+adele'
feel_coming = 'https://www.ultimate-guitar.com/search.php?search_type=title&order=&value=i+feel+it+coming'
sorry = 'https://www.ultimate-guitar.com/search.php?search_type=title&order=&value=sorry+justin+bieber'
search_soup = soup_page(sorry)
table = search_soup.find_all('table',{'class':'tresults'})[0]

# %%
rows = table.find_all('tr')[1:len(table)]

# %%
for row in rows:
    if get_type(row) == 'chords':
        if (get_rating(row) != None):
            print(get_rating(row),"\t", get_url(row))
# Out:
# 733.0 	 https://tabs.ultimate-guitar.com/j/justin_bieber/sorry_crd.htm
# 27.0 	 https://tabs.ultimate-guitar.com/j/justin_bieber/sorry_ver2_crd.htm
# 9.0 	 https://tabs.ultimate-guitar.com/j/justin_bieber/sorry_ver3_crd.htm

# %%
song1 = get_top100_query(2016)[0]

# %%
temp_soup = soup_page(search_url(song1))

# %%
temp_soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
# <script>
# (function(d,s,l){if (!(typeof Promise === 'function' && 'Promise' in window)) {var s=d.createElement('script'),h=d.getElementsByTagName('head')[0];s.src=l;s.type = "text/javascript";h.appendChild(s);}}(document, 'script', '//cdn.ustatik.com/plus/vendor/es6-promise.min_ver1492455806.js'));
# </script>
# <script>
#     var UGAPP = { config: {
#         main_server: 'ultimate-guitar.com',
#         ps_server: 'plus.ultimate-guitar.com',
#         static_server: 'https://cdn.ustatik.com',
#         statik_cache: '_ver1492455806',
#         time: 1492462277000,
#         pageTime: Date.now && Date.now(),
#         user: {
#             id: 0,
#             username: 'Unregistered',
#         },
#         is_mobile: false,
#         socketCluster: {
#             serviceKey: 'f0557aa8-2d06-43d9-9c16-f885bc710b97:main',
#             channelPrefix: 'f0557aa8-2d06-43d9-9c16-f885bc710b97:main#prod',
#             hostname: 'ws.ultimate-guitar.com',
#             port: 443,
#             channelName: '',
#         },
#         metricaId: 18746557,
#         captcha_id: '6LfCo_8SAAAAALEMHnlK18j8IemlAdvmxwRnQe2v',
#         contoller_id: 'search',
#         country: 'US'
#     },store: {
#                 forms: {},
#         theme: 'dark',
#         commentForm: {
#             is_new: 0        }
#     }};
# </script>
# <script>
# function loadAsync(url, callback) {
#     var script = document.createElement("script"), loaded;
#     script.async = true;
#     script.src = url;
#
#     if (callback)
#     {
#         script.onreadystatechange = script.onload = function() {
#             if (!loaded)
#             {
#                 callback();
#                 loaded = true;
#             }
#         };
#     }
#
#     document.getElementsByTagName('body')[0].appendChild(script);
# }
# </script> <script type="text/javascript">var js_img_domain = 'cdn.ustatik.com';</script> <script async="" src="//cdn.ustatik.com/public/js/ad/tabpro_ver1492455806.js"></script>
# <title>Love Yourself Justin Bieber, 36 chords &amp; tabs found @ Ultimate-Guitar.Com Search</title>
# <meta content="" name="description">
# <meta content="" name="keywords">
# <meta content="#000000" name="theme-color">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="width=1280, minimum-scale=0.1, maximum-scale=2.0" name="viewport"/>
# <link href="/manifest.json" rel="manifest">
# <link href="//cdn.ustatik.com/_img/bootstrap/ug/img/favicon.ico" rel="icon" type="image/x-icon">
# <link href="//cdn.ustatik.com/_img/bootstrap/ug/img/touchicons/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="//cdn.ustatik.com/_img/bootstrap/ug/img/touchicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="//cdn.ustatik.com/_img/bootstrap/ug/img/touchicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="//cdn.ustatik.com/_img/bootstrap/ug/img/touchicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <meta content="Ultimate Guitar" name="application-name"/>
# <meta content="#f2f2f2" name="msapplication-TileColor"/>
# <meta content="//cdn.ustatik.com/_img/bootstrap/ug/img/touchicons/mediumtile.png" name="msapplication-TileImage">
# <link href="//cdn.ustatik.com/_img/common_ver1492455806.css" rel="STYLESHEET" type="text/css">
# <link href="//cdn.ustatik.com/public/css/classic/classic_ver1492455806.css" rel="STYLESHEET" type="text/css">
# <link href="https://chrome.google.com/webstore/detail/cpjmidngbpgnobnojpjgkidfnapkbieg" rel="chrome-webstore-item">
# <link href="//cdn.ustatik.com/opensearch/opensearch.xml" rel="search" title="Ultmate-Guitar tabs &amp; chords search" type="application/opensearchdescription+xml"/><meta content="_csrf" name="csrf-param">
# <meta content="U3ZTNHdPdmoDHQkCTxUsOCA6HmIuIy86Pi46Uh0mLB8eRTRtAXcdGA==" name="csrf-token">
# <script>window.gpads = {que: []};</script>
# <!-- region US -->
# <link as="script" href="https://ads.pubmatic.com/AdServer/js/gshowad.js" rel="preload">
# <link as="script" href="//c.amazon-adsystem.com/aax2/amzn_ads.js" rel="preload">
# <script async="" src="//cdn.ustatik.com/vendor/prebid_gt2_ast_ver1492455806.js"></script>
# <script>
#
#     if (document.domain.indexOf('lan') === -1)
#     {
#                 document.domain = 'ultimate-guitar.com';
#             }
#
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#
#     pbjs.que.push(function() {
#         pbjs.gpads.init(document, {
#             adUnits: [{"code":"ad_cs_2010324_728_90","dfpCode":"UG_ATF_728","sizes":[[728,90],[970,250]],"placement":"ATF","refresh":{"after":[{"pageActive":60000},{"unitVisible":5000}],"limit":20},"bids":[{"bidder":"appnexus","params":{"placementId":"8549999","keywords":{"subcat":"search"}}},{"bidder":"amazon","anImpsTrackerId":28015,"params":{"mode":"sync"}},{"bidder":"brealtime","anImpsTrackerId":28020,"params":{"placementId":"7171600"}},{"bidder":"pulsepoint","anImpsTrackerId":28025,"params":{"cf":"728x90","cp":"553934","ct":"484579"}},{"bidder":"aol","anImpsTrackerId":28029,"params":{"network":"9527.1","placement":"3211475"}},{"bidder":"sovrn","anImpsTrackerId":28128,"params":{"tagid":"441693"}},{"bidder":"pubmatic","anImpsTrackerId":28135,"params":{"publisherId":72623,"adSlot":"3131195@728x90"}},{"bidder":"rubicon","anImpsTrackerId":28139,"params":{"accountId":"15178","siteId":"93918","zoneId":"441934"}},{"bidder":"sonobi","anImpsTrackerId":28897,"params":{"dom_id":"ad_cs_2010320_728_90","placement_id":"cdcb6dbf3c18a44c77a6"}},{"bidder":"indexExchange","anImpsTrackerId":29976,"params":{"id":"2","siteID":"179681"}},{"bidder":"springserve","anImpsTrackerId":30270,"params":{"impId":"7333-202-928"}},{"bidder":"districtM","anImpsTrackerId":30809,"params":{"placementId":"9325327"}},{"bidder":"openx","anImpsTrackerId":31517,"params":{"delDomain":"ultimate-guitar-d.openx.net","unit":"538591653"}},{"bidder":"komoona","anImpsTrackerId":31789,"params":{"hbid":"d861ba40d70b46b7af2a58e3b6f123b8","placementId":"21ba853755ce7bc85bfbb222bea9ad78"}},{"bidder":"aardvark","anImpsTrackerId":31996,"params":{"ai":"ozpG","sc":"4535"}},{"bidder":"conversant","anImpsTrackerId":33892,"params":{"site_id":"110113","secure":"true"}},{"bidder":"rhythmone","anImpsTrackerId":34887,"params":{"placementId":"61405"}},{"bidder":"criteo","anImpsTrackerId":35701,"params":{"zoneId":"734421"}}]},{"code":"ad_cs_2010324_160_600","dfpCode":"UG_ATF_160","sizes":[[160,600]],"placement":"ATF","refresh":{"after":[{"pageActive":60000},{"unitVisible":5000}],"limit":20},"bids":[{"bidder":"appnexus","params":{"placementId":"8549999","keywords":{"subcat":"search"}}},{"bidder":"amazon","anImpsTrackerId":28013,"params":{"mode":"sync"}},{"bidder":"brealtime","anImpsTrackerId":28018,"params":{"placementId":"7171584"}},{"bidder":"pulsepoint","anImpsTrackerId":28023,"params":{"cf":"160x600","cp":"553934","ct":"484577"}},{"bidder":"aol","anImpsTrackerId":28027,"params":{"network":"9527.1","placement":"3211476"}},{"bidder":"sovrn","anImpsTrackerId":28126,"params":{"tagid":"441691"}},{"bidder":"pubmatic","anImpsTrackerId":28133,"params":{"publisherId":"72623","adSlot":"3131193@160x600"}},{"bidder":"rubicon","anImpsTrackerId":28137,"params":{"accountId":"15178","siteId":"93918","zoneId":"441934"}},{"bidder":"sonobi","anImpsTrackerId":28895,"params":{"dom_id":"ad_cs_2010320_160_600","placement_id":"de32675870a56a0586a0"}},{"bidder":"indexExchange","anImpsTrackerId":29974,"params":{"id":"1","siteID":"177325"}},{"bidder":"springserve","anImpsTrackerId":30267,"params":{"impId":"7333-202-927"}},{"bidder":"districtM","anImpsTrackerId":30808,"params":{"placementId":"9325303"}},{"bidder":"openx","anImpsTrackerId":31516,"params":{"delDomain":"ultimate-guitar-d.openx.net","unit":"538591659"}},{"bidder":"komoona","anImpsTrackerId":31788,"params":{"hbid":"d861ba40d70b46b7af2a58e3b6f123b8","placementId":"ea8f6e8955e9ca49f83f3d41bd722623"}},{"bidder":"aardvark","anImpsTrackerId":31995,"params":{"ai":"ozpG","sc":"hykJ"}},{"bidder":"conversant","anImpsTrackerId":33890,"params":{"site_id":"110113","secure":"true"}},{"bidder":"rhythmone","anImpsTrackerId":34886,"params":{"placementId":"61405"}},{"bidder":"criteo","anImpsTrackerId":35699,"params":{"zoneId":"734425"}}]},{"code":"ad_cs_4219367_300_250","dfpCode":"UG_BTFL_300","sizes":[[300,250]],"placement":"BTFL","refresh":{"after":[{"pageActive":60000},{"unitVisible":5000}],"limit":20},"bids":[{"bidder":"appnexus","params":{"placementId":"8550000","k ...
#             hb_defaults: [{"pid":2010329,"size":160,"p":"ATF","nf":0.69},{"pid":2010329,"size":728,"p":"ATF","nf":0.82},{"pid":3278979,"size":160,"p":"ATF","nf":0.1},{"pid":3278979,"size":728,"p":"ATF","nf":0.1},{"pid":4297269,"size":160,"p":"ATF","nf":1.45},{"pid":4297269,"size":300,"p":"ATF","nf":0.1},{"pid":4297269,"size":728,"p":"ATF","nf":1.45},{"pid":6600081,"size":160,"p":"BTFR","nf":0.1},{"pid":6600081,"size":300,"p":"BTFR","nf":0.1},{"pid":9399148,"size":300,"p":"BTFL","nf":0.1},{"pid":9399523,"size":300,"p":"BTFL","nf":0.88},{"pid":9399525,"size":300,"p":"BTFR","nf":0.9}],
#             app_label: 'ug:search_desktop_version',
#             timeout: 1500,
#             cpm_floor: 2,
#             trackViewability: true,
#             page_type: 'desktop',
#             country: 'US',
#             creatives: [{"id":55049465,"name":"Technorati_US_UG_300BTFL","code":"...","anImpsTrackerId":33900},{"id":55050227,"name":"Technorati_UG_US_300BTFR (only TAB)","code":"...","anImpsTrackerId":33901},{"id":59148121,"name":"Sekindo 500x800 sup","code":"...","anImpsTrackerId":33902},{"id":64817905,"name":"TF 300M apple music","code":"","anImpsTrackerId":35225}],
#             variation: 'B'
#                     });
#
#         window.gpads.default = pbjs.gpads.processDefault;
#     });
#     </script>
# <script src="//c.amazon-adsystem.com/aax2/amzn_ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         amznads.getAdsCallback('3246', function(){
#         pbjs.que.push(function() {
#             pbjs.emitExternalEvent('amazonReady', {});
#         });
#     });
#     </script>
# </link></link></meta></meta></link></link></link></meta></link></link></meta></meta></meta></meta></head>
# <body background="//cdn.ustatik.com/_img/bgd.gif" bgcolor="#000000" class="is_desktop" leftmargin="0" topmargin="0">
# <script>
#     var SplashParams = {"is_splash_user":false,"ga_tracker":null,"GA_events":[],"YM_events_map":[],"cookie_domain":"ultimate-guitar.com","cookie_big_splash_shown":"show_ugt_splash","page_type":"tab_search","device_type":null,"AB_value":null,"trackingOptions":[],"counters":{"big":{"cookie_count_name":"was_bs_shown3","max_splash_count":5}},"counters_ttl":360,"tab_links":[]};
#     SplashParams.items = {};
#
#     </script>
# <center id="page-wrapper">
# <div align="left" class="page-wrap page-wrap__lg" style="background:#000;width:986px">
# <!--HEADER-->
# <div class="width-h">
# <div class="header bdrunion">
# <div class="h-menu bdrunion">
# <a class="plusik f-right" href="https://plus.ultimate-guitar.com/tab-pro/?utm_source=UltimateGuitar&amp;utm_medium=Header&amp;utm_campaign=UG+Tab+Pro&amp;utm_content=Search+Index"><span class="play_tab_list__artist" title="Tab Pro"></span><span>Tab Pro</span></a>
# <a href="https://www.ultimate-guitar.com/">guitar tabs</a> /
#                     <a href="https://www.ultimate-guitar.com/feed/">feed</a> /
#                 <a href="https://www.ultimate-guitar.com/news/">news</a> /
#         <a href="https://www.ultimate-guitar.com/reviews/">reviews</a> /
#         <a href="https://www.ultimate-guitar.com/lessons/">lessons</a> /
#         <a href="https://www.ultimate-guitar.com/forum/">forums</a> /
#         <a href="https://www.ultimate-guitar.com/collections/">tab collections</a>
# </div>
# <div class="h-logo">
# <table cellpadding="2" cellspacing="0">
# <tr>
# <td class="logo-col">
# <div class="logoplace ">
# <a class="logolink db" href="https://www.ultimate-guitar.com/"></a>
# </div>
# <div class="updmsg">
# 							You've searched for <b>'love yourself justin bieber'</b> : <b>36</b> tabs found						</div>
# </td>
# <td class="div-col bdrunion"></td>
# <td class="login-col">
# <div class="loginplace">
# <div class="dn" id="login_user_auth">
# <div class="log_ld">
# <a class="log_ico" href="https://www.ultimate-guitar.com/forum/profile/update-avatar"><table cellpadding="0" cellspacing="0"><tr><td align="center" id="header_login_ava" valign="middle"><img src="https://cdn.ustatik.com/users/0/0/0/0.gif?d=d"/></td></tr></table></a>
# <div class="log_out"><a class="logout sm1" href="#" id="js-user-logout"><b></b>Logout</a></div>
# </div>
# <div class="log_inf">
# <div class="fader2 log_name">
# <a class="userico" href="http://profile.ultimate-guitar.com/Unregistered/" id="username_header">
#                                     Unregistered                                    </a>
# <span style="position: relative">
# <a class="ug-iq--rating__main-header" href="https://www.ultimate-guitar.com/user/activity/iq?user_id=0" target="_blank" title="UG IQ">
#                                             0                                        </a>
# </span>
# </div>
# <div class="proflinks">
# <div class="right">
# <a class="nowrap" href="https://plus.ultimate-guitar.com/tab-pro/?utm_source=UltimateGuitar&amp;utm_medium=User+Panel&amp;utm_campaign=UG+Tab+Pro"><b class="dot_usr f-left"></b>UG Plus</a>
# <a href="https://www.ultimate-guitar.com/user/favorite"><b class="dot_usr f-left"></b>Favorites</a>
# </div>
# <div class="left">
# <a href="http://my.ultimate-guitar.com/"><b class="dot_usr f-left"></b>Profile</a>
# <span class="nowrap head-hist-btn js-tabs-history" href="#"><b class="dot_usr f-left"></b><span>History</span>
# <div class="history-tooltip-container js-tabs-history-tooltip">
# <div class="history-tooltip" id="history-tooltip">
# <div class="inner">
# <div class="head">Recently viewed tabs</div>
# <div class="history-items">
# <div class="no-tabs">
#                         No tabs to display.
#                     </div>
# </div>
# <div class="bottom">
# <a class="f-left" href="https://www.ultimate-guitar.com/top/top100.htm">Popular tabs</a>
# <a class="f-right" href="https://www.ultimate-guitar.com/tabs/">Fresh tabs</a>
# </div>
# </div>
# </div>
# </div>
# </span>
# </div>
# </div>
# <div class="js-notifications-slot ug-notifications dropdown"></div>
# </div>
# </div>
# <div class="log_h " id="login_user_guest">
# <div class="log_txt">
#                                 Welcome home, <b>Stranger</b><br>
#                                 Please <a class="auth_sign_in" href="#">Sign in</a> or <a class="auth_sign_up" href="#">Sign up</a>
# </br></div>
# <div class="line_txt">
# <div></div>
# <span class="inline_txt">you can also use</span>
# </div>
# <div class="s_up">
# <a class="log_fb auth_s" href="https://www.ultimate-guitar.com/user/auth/oauth?service=facebook"><span><b></b></span>Facebook</a>
# <a class="log_g auth_s auth_g" href="https://www.ultimate-guitar.com/user/auth/oauth?service=google"><span><b></b></span>Google</a>
# </div>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <!--ADSSEARCH-->
# <div id="advanced_search" style="margin: 0 3px">
# <table cellpadding="0" cellspacing="0" style="background:#000; width:100%; margin:0px auto">
# <tr class="js-ug-contest-replace">
# <td class="b bdrunion" style="display: block!important; padding: 7px 0 10px 0; vertical-align: middle; text-align: center; min-height: 109px;">
# <span class="head_ad_UG">
# <center>
# <div style="max-height: 250px;padding-top: 11px;">
# <!--googleoff: all-->
# <div class="hide criteo_block">
# <div id="cto_728x90" style="width:728px; height:90px;"></div>
# </div>
# <!--googleon: all--> <div class="js-ab-regular">
# <script id="ad_cs_2010324_728_90">
#                                            window.gpads.que.push({cs: 'ad_cs_2010324_728_90', p: 2010324, w: 728, h: 90, q_str: '&subcat=search&promo_sizes=970x250,970x90&promo_alignment=center', amzn: '9x2'});
#                                        </script>
# </div>
# </div>
# </center>
# </span>
# </td>
# </tr>
# <tr>
# <td class="b takeover-place-main bdrunion">
# </td>
# </tr>
# <tr>
# <td align="center" class="b bdrunion" style="padding:2px;position: relative;z-index: 250000;background: black;">
# <table cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <table cellpadding="0" cellspacing="0" class="search-main" width="100%">
# <tr>
# <td align="right" class="tdsearch">
# <div id="search_bar_simple">
# <form action="https://www.ultimate-guitar.com/search.php" autocomplete="off" class="mp0 js-search-form" data-searchforum="https://www.ultimate-guitar.com/forum/search/search" data-searchsite="https://www.ultimate-guitar.com/search.php">
# <table cellpadding="0" cellspacing="0" class="search-table">
# <tr>
# <td width="20%">
# <div class="searchsel">
# <div class="selwin">
# <a href="#" value="title">TABS</a>
# <a href="#" value="band">ARTISTS</a>
# <b> </b>
# <a href="#" value="news">NEWS</a>
# <a href="#" value="reviews">REVIEWS</a>
# <a href="#" value="lessons">LESSONS</a>
# <b> </b>
# <a href="#" value="users">USERS</a>
# <input id="w" name="search_type" type="hidden" value="title">
# <input id="search-order" name="order" type="hidden" value="">
# </input></input></div>
# <div class="selcurr"><b class="f-right"></b> TABS</div>
# </div>
# </td>
# <td>
# <div class="searchinp">
# <input class="search_input" id="search_input" name="value" size="34" type="text" value="love yourself justin bieber">
# </input></div>
# </td>
# <td width="70">
# <div class="searchbut"><input type="submit" value="Search!"/></div>
# </td>
# </tr>
# </table>
# </form>
# </div>
# <div id="search_bar_advanced" style="display:none">
# <form action="search.php">
# <input id="view_state" name="view_state" type="hidden" value="advanced">
# <table cellpadding="0" cellspacing="0" class="ml-10" style="text-align:left" width="620">
# <tr>
# <td class="legpad adv_one_field dn">
# <div style="position:absolute; margin-left:-20px; margin-top:5px;"><a href="#" onclick="return SwitchAdvancedForm();"><img height="11" src="//cdn.ustatik.com/img/search/search.gif" width="14"/></a></div>
# <fieldset class="fs_title">
# <legend> Title </legend>
# <table cellpadding="0" cellspacing="0" style="margin-top:5px" width="100%">
# <tr>
# <td align="left"><div class="searchinp-2"><input class="input_title" disabled="" name="title" type="text" value="love yourself justin bieber"/></div></td>
# </tr>
# </table>
# </fieldset>
# </td>
# <td class="legpad adv_two_fields">
# <div style="position:absolute; margin-left:-20px; margin-top:5px;"><a href="#" onclick="return SwitchAdvancedForm();"><img height="11" src="//cdn.ustatik.com/img/search/search.gif" width="14"/></a></div>
# <fieldset class="fs_title-2">
# <legend> Artist name </legend>
# <table cellpadding="0" cellspacing="0" style="margin-top:5px" width="100%">
# <tr>
# <td><div class="searchinp-2"><input name="band_name" type="text" value=""/></div></td>
# </tr>
# </table>
# </fieldset>
# </td>
# <td class="legpad adv_two_fields">
# <fieldset class="fs_title-2">
# <legend> Song name </legend>
# <table cellpadding="0" cellspacing="0" style="margin-top:5px" width="100%">
# <tr>
# <td><div class="searchinp-2"><input name="song_name" type="text" value=""/></div></td>
# </tr>
# </table>
# </fieldset>
# </td>
# <td valign="top" width="70"><div class="cus"><input class="submit" id="submit_input" type="submit" value="Search!"/></div></td>
# </tr>
# </table>
# <table cellpadding="0" cellspacing="0" class="asbgd" height="121" width="620">
# <tr>
# <td align="center" class="atitle" valign="top" width="105">Type
#                                                         <p class="mt-5">
# <select class="aselect scroll-pane" id="select1" multiple="multiple" name="type[]" size="5">
# <option value="300">chords</option>
# <option value="200">tab</option>
# <option value="500">guitar pro</option>
# <option value="600">power</option>
# <option value="400">bass</option>
# <option value="700">drums</option>
# <option value="100">video</option>
# <option value="800">ukulele</option>
# </select>
# </p>
# </td>
# <td align="center" class="atitle" valign="top" width="105">Type 2
#                                                         <p class="mt-5">
# <select class="aselect scroll-pane" id="select2" multiple="multiple" name="type2[]" size="5">
# <option value="40000">whole song</option>
# <option value="10000">album</option>
# <option value="20000">intro</option>
# <option value="30000">solo</option>
# <option value="50000">live</option>
# <option value="60000">acoustic</option>
# </select>
# </p>
# </td>
# <td align="center" class="atitle" valign="top" width="105">Rating
#                                                         <p class="mt-5">
# <select class="aselect scroll-pane" id="select3" multiple="multiple" name="rating[]" size="5">
# <option value="5">*****</option>
# <option value="4">****</option>
# <option value="3">***</option>
# <option value="2">**</option>
# <option value="1">*</option>
# </select>
# </p>
# </td>
# <td align="center" class="atitle" valign="top" width="105">Level
#                                                         <p class="mt-5">
# <select class="aselect scroll-pane" id="select4" multiple="multiple" name="level[]" size="5">
# <option value="1">novice</option>
# <option value="2">intermediate</option>
# <option value="3">advanced</option>
# </select>
# </p>
# </td>
# <td align="center" class="atitle" valign="top" width="105">Tuning
#                                                         <p class="mt-5">
# <select class="aselect scroll-pane" id="select5" multiple="multiple" name="tuning[]" size="5">
# <option value="standard">Standard</option>
# <option value="half-step down">Half-Step Down</option>
# <option value="b tuning">B Tuning</option>
# <option value="c tuning">C Tuning</option>
# <option value="c# tuning">C# Tuning</option>
# <option value="d tuning">D Tuning</option>
# <option value="drop a">Drop A</option>
# <option value="drop a#">Drop A#</option>
# <option value="drop b">Drop B</option>
# <option value="drop c">Drop C</option>
# <option value="drop c#">Drop C#</option>
# <option value="drop d">Drop D</option>
# <option value="open c">Open C</option>
# <option value="open d">Open D</option>
# <option value="open e">Open E</option>
# <option value="open g">Open G</option>
# <option value="celtic">Celtic</option>
# </select>
# </p>
# </td>
# <td align="right" class="atitle" style="padding-left:11px;" valign="top">
# <div class="s_version"><span style="margin-left:7px">Version</span>
# <p class="mt-5">
# <select class="aselect" id="select6" name="version_la">
# <option value="">Any</option>
# <option value="1">Acoustic</option>
# <option value="2">Live</option>
# </select>
# </p>
# </div>
# </td>
# <td>
# </td>
# </tr>
# </table>
# </input></form>
# </div>
# <div class="alphadiv">
# <a class="alpha_b13" href="https://www.ultimate-guitar.com/tabs/">FRESH TABS</a>
# <b class="ver" style="color:#777">|</b>
# <span class="alph">
# <a class="wb" href="https://www.ultimate-guitar.com/bands/0-9.htm">0-9</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/a.htm">A</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/b.htm">B</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/c.htm">C</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/d.htm">D</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/e.htm">E</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/f.htm">F</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/g.htm">G</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/h.htm">H</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/i.htm">I</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/j.htm">J</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/k.htm">K</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/l.htm">L</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/m.htm">M</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/n.htm">N</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/o.htm">O</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/p.htm">P</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/q.htm">Q</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/r.htm">R</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/s.htm">S</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/t.htm">T</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/u.htm">U</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/v.htm">V</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/w.htm">W</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/x.htm">X</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/y.htm">Y</a>
# <a class="wb" href="https://www.ultimate-guitar.com/bands/z.htm">Z</a>
# </span>
# <b class="ver" style="color:#777">|</b>
# <a class="alpha_b13" href="https://www.ultimate-guitar.com/top/">TOP 100 TABS</a>
# </div>
# </td>
# <td class="searchadv">
# <span class="dib">
# <a class="gray aria undl advanced" href="https://www.ultimate-guitar.com/advanced_search.html"><b class="dibimg"></b> Advanced</a>
# <a class="expa expand_icon" href="/advanced_search.html" id="expand_search_link" onclick="return SwitchSearch();"><b></b>Expand</a>
# </span>
# </td>
# <td valign="top" width="2"><div class="polosochka"></div></td>
# <td align="left" class="tdsubmit">
# 									+ <a class="w10verd js-submit-tab-btn" href="https://www.ultimate-guitar.com/contribution/submit/tabs">Submit tab</a><br>
# 									+ <a class="w10verd auth_sign_in auth_continue" href="https://www.ultimate-guitar.com/submit/reviews.php">Submit review</a><br>
# 									+ <a class="w10verd" href="https://www.ultimate-guitar.com/submit/news.php">Submit article</a><br>
# </br></br></br></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </div>
# </div><!--/ADSSEARCH-->
# <script>
#     var ug_user_id = 0;
#     var has_etp = 0;
# </script>
# <link href="//cdn.ustatik.com/img/search/style_ver1492455806.css" rel="stylesheet" type="text/css">
# <style>
#     .cluetip-tabinfo #cluetip-outer
#     {
#         border: 1px solid rgb(88, 88, 88);
#         padding: 5px;
#         background:#262626;
#         color:#ddddcc;
#         font:12px Verdana;
#     }
#     #npd77 { display: none }
#     .width-h {margin: 0;}
#     .content {margin: 0 3px;}
# </style>
# <div class="content">
# <table cellpadding="0" cellspacing="0" width="980">
# <tr>
# <td class="sopt js-search-filters" valign="top">
# <h3 class="filtypes"><b></b>type filter</h3>
# <ul class="soptcont js-search-filters-block" data-filter-type="type">
# <li>
# <span class="f-right gray3">36</span> <b class="gray2">All</b>
# </li>
# <li>
# <span class="f-right gray3">5</span> <a href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=myweight&amp;type=300">Chords</a>
# </li>
# <li>
# <span class="f-right gray3">18</span> <a href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=myweight&amp;type=200">Tab</a>
# </li>
# <li>
# <span class="f-right gray3">3</span> <a href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=myweight&amp;type=500" rel="nofollow">Guitar Pro</a>
# </li>
# <li>
# <span class="f-right gray3">3</span> <a href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=myweight&amp;type=400" rel="nofollow">Bass</a>
# </li>
# <li>
# <span class="f-right gray3">2</span> <a href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=myweight&amp;type=100" rel="nofollow">Video</a>
# </li>
# <li>
# <span class="f-right gray3">5</span> <a href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=myweight&amp;type=800" rel="nofollow">Ukulele</a>
# </li>
# </ul>
# <div class="ads_v">
# <div class="criteo_block hide" id="cto_160x600" style="width:160px; height: 600px; margin: 0 auto;"></div>
# <center>
# <script id="ad_cs_2010324_160_600">
#                                 window.gpads.que.push({cs: 'ad_cs_2010324_160_600', p: 2010324, w: 160, h: 600, q_str: '&subcat=search'});
#                             </script>
# </center>
# </div>
# </td>
# <td align="left" class="sres" valign="top">
# <table cellpadding="0" cellspacing="0" class="results" width="100%">
# <tr>
# <td width="300">
# <h1 class="yell">
#                             Love Yourself Justin Bieber chords &amp; tabs                        </h1>
# </td>
# <td align="left" valign="center">
# <div class="sort" id="all">
# <font class="all sort_t"><b></b>Relevancy</font>
# </div>
# <div class="sort" id="abc">
# <a class="abc" href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=title_srt" rel="nofollow"><b></b>ABC</a>
# </div>
# <div class="sort" id="high">
# <a class="high" href="/search.php?title=love+yourself+justin+bieber&amp;approved%5B1%5D=1&amp;page=1&amp;tab_type_group=text&amp;app_name=ugt&amp;order=myweight&amp;rating%5B0%5D=4&amp;rating%5B1%5D=5" rel="nofollow"><b></b>High rated</a>
# </div>
#
#                         </td>
# <td align="right" class="res_tab" width="45">results<br>total</br></td>
# <td class="res_all" width="65">36</td>
# </tr>
# </table>
# <div class="br"> </div>
# <table cellspacing="1" class="tresults ">
# <thead>
# <tr>
# <th width="175">Artist :</th>
# <th width="363">Song :</th>
# <th width="115">Rating :</th>
# <th width="80">Type :</th>
# </tr>
# </thead>
# <tr>
# <td valign="top"><a class="song search_art js-search-spelling-artist" href="/tabs/justin_bieber_tabs.htm" onclick="window.trackCorrected('ARTIST')"><b>Justin</b> <b>Bieber</b></a></td>
# <td class="search-version--td">
# <span>
# <div class="tab-list--search--duration">2:14</div>
# <a class="song js-tp_link" href="https://plus.ultimate-guitar.com/tp/?utm_source=UltimateGuitar&amp;utm_medium=Search&amp;utm_campaign=UG+Search&amp;artist=Justin+Bieber&amp;song=Love+Yourself&amp;t=MTc4NjkxMXw%3D" onclick="try{ga('send', 'event', 'Search', 'Click', 'Tab Pro Tabs Click');window.trackCorrected('TPW')}catch(e){};" target="_blank"><b>Love</b> <b>Yourself</b></a>
# <a class="js-tp_link tab-list--search--icons" href="https://plus.ultimate-guitar.com/tp/?utm_source=UltimateGuitar&amp;utm_medium=Search&amp;utm_campaign=UG+Search&amp;artist=Justin+Bieber&amp;song=Love+Yourself&amp;t=MTc4NjkxMXw%3D" onclick="try{ga('send', 'event', 'Search', 'Click', 'Tab Pro Tabs Click');window.trackCorrected('TPW')}catch(e){};" target="_blank">
# <b class="play_tab_list__search-benefits js-tp-link" data-id="1780199" data-source="search">
# <div class="link-tooltip--text hide dark js-tp-tooltip">
# <b>Tab Pro tab</b><br>
#                             Online tab player with practice tools: slow down, loop and mute any track
#                                             </br></div>
# </b>
# </a>
# <div class="tab-list--search--tracks">Tracks: acoustic guitar (steel)</div>
# </span>
# </td>
# <td class="gray4 tresults--rating" valign="top">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">64</b> ]</span>
# </td>
# <td valign="top"><strong>tab pro</strong></td>
# </tr>
# <tr class="stripe">
# <td valign="top"> </td>
# <td class="search-version--td">
# <span>
# <a class="song js-tp_link" href="https://plus.ultimate-guitar.com/tp/?utm_source=UltimateGuitar&amp;utm_medium=Search&amp;utm_campaign=UG+Search&amp;utm_content=Chord+Pro&amp;utm_term=956&amp;artist=Justin+Bieber&amp;song=Love+Yourself" onclick="try{ga('send', 'event', 'Search', 'Click', 'Tab Pro Tabs Click');window.trackCorrected('TPW')}catch(e){};" target="_blank"><b>Love</b> <b>Yourself</b></a>
# <a class="js-tp_link tab-list--search--icons" href="https://plus.ultimate-guitar.com/tp/?utm_source=UltimateGuitar&amp;utm_medium=Search&amp;utm_campaign=UG+Search&amp;utm_content=Chord+Pro&amp;utm_term=956&amp;artist=Justin+Bieber&amp;song=Love+Yourself" onclick="try{ga('send', 'event', 'Search', 'Click', 'Tab Pro Tabs Click');window.trackCorrected('TPW')}catch(e){};" target="_blank">
# <b class="play_tab_list__search-benefits js-tp-link" data-id="1780199" data-source="search">
# <div class="link-tooltip--text link-tooltip--text__chord-pro hide dark js-tp-tooltip">
# <b>Chord Pro</b><br>
#                             A chord tab, closest to the original song.<br>
#                             Comes with interactive tabs for specific<br>
#                             parts of a song.
#                                             </br></br></br></div>
# </b>
# </a>
# <div class="tab-list--search--tracks">With interactive tabs for verse, verse 1, pre chorus, pre chorus 1, chorus, chorus 1, verse 2, pre chorus 2, chorus 2, instrumental &amp; chorus 3</div>
# </span>
# <script>window.addEventListener("load", function() {try {yaCounter18746557.reachGoal("CHORD_PRO_SEARCH_RESULT_TP_LINK_SHOWN");} catch(e) {}});</script> </td>
# <td class="gray4 tresults--rating" valign="top">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# </span>
# <span>[ <b class="ratdig">4502</b> ]</span>
# </td>
# <td valign="top"><strong>chord pro</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> </a>
# </div>
# <div class="dn" id="info_1780199">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# </span>
# <span>[ <b class="ratdig">4502</b> ]</span></td>
# <td><strong>chords</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver2_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 2)                                                                            </a>
# </div>
# <div class="dn" id="info_1780295">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">intermediate</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# </span>
# <span>[ <b class="ratdig">191</b> ]</span></td>
# <td><strong>chords</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver3_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 3)                                                                            </a>
# </div>
# <div class="dn" id="info_1797946">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# </span>
# <span>[ <b class="ratdig">76</b> ]</span></td>
# <td><strong>chords</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver4_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 4)                                                                            </a>
# </div>
# <div class="dn" id="info_1828613">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">intermediate</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# </span>
# <span>[ <b class="ratdig">16</b> ]</span></td>
# <td><strong>chords</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver5_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 5)                                                                            </a>
# </div>
# <div class="dn" id="info_1798880">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">intermediate</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">9</b> ]</span></td>
# <td><strong>chords</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_intro_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> Intro                                                                            </a>
# </div>
# <div class="dn" id="info_1781095">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">180</b> ]</span></td>
# <td><strong>tab</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_intro_ver2_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> Intro (ver 2)                                                                            </a>
# </div>
# <div class="dn" id="info_1842508">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">7</b> ]</span></td>
# <td><strong>tab</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_solo_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> Solo                                                                            </a>
# </div>
# <div class="dn" id="info_1835833">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">21</b> ]</span></td>
# <td><strong>tab</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_solo_ver2_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> Solo (ver 2)                                                                            </a>
# </div>
# <div class="dn" id="info_1807452">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# </span>
# <span>[ <b class="ratdig">84</b> ]</span></td>
# <td><strong>tab</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_solo_ver3_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> Solo (ver 3)                                                                            </a>
# <div class="tabinfo link-tooltip ">
#                                         info
#                                         <div class="link-tooltip--text dark js-tooltip-content">
#                                             Easy tab for the solo of Justin Biebers Love Yourself. Easy to play and sounds just like the original. Inspired by: https://www.youtube.com/watch?v=a7nSJTNGzB0.                                        </div>
# </div>
# </div>
# <div class="dn" id="info_1969475">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating"></td>
# <td><strong>tab</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> </a>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">50</b> ]</span></td>
# <td><strong>tab</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver2_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 2)                                                                            </a>
# </div>
# <div class="dn" id="info_1781167">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">66</b> ]</span></td>
# <td><strong>tab</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver3_tab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 3)                                                                            </a>
# </div>
# <div class="dn" id="info_1781366">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# ...
# <b>Love</b> <b>Yourself</b> (ver 2)                                                                            </a>
# </div>
# </td>
# <td class="gray4 tresults--rating"></td>
# <td><strong>bass</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver3_btab.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 3)                                                                            </a>
# </div>
# <div class="dn" id="info_1858681">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">intermediate</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">3</b> ]</span></td>
# <td><strong>bass</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_video_lesson.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> </a>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# </span>
# <span>[ <b class="ratdig">7</b> ]</span></td>
# <td><strong>video</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver2_video_lesson.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 2)                                                                            </a>
# </div>
# <div class="dn" id="info_1851230">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">54</b> ]</span></td>
# <td><strong>video</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_solo_ukulele_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> Solo                                                                            </a>
# </div>
# <div class="dn" id="info_1850953">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">29</b> ]</span></td>
# <td><strong>ukulele</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ukulele_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> </a>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">69</b> ]</span></td>
# <td><strong>ukulele</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver2_ukulele_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 2)                                                                            </a>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">419</b> ]</span></td>
# <td><strong>ukulele</strong></td>
# </tr>
# <tr class=" ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver3_ukulele_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 3)                                                                            </a>
# <div class="tabinfo link-tooltip ">
#                                         info
#                                         <div class="link-tooltip--text dark js-tooltip-content">
#                                             Allen Ortega's version. Easier than the version 2 and slightly more accurate.                                        </div>
# </div>
# </div>
# <div class="dn" id="info_1845171">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating">
# <span class="rating" title="4.5">
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__active"></span>
# <span class="icon-rating-sm icon-rating-sm__half"></span>
# </span>
# <span>[ <b class="ratdig">17</b> ]</span></td>
# <td><strong>ukulele</strong></td>
# </tr>
# <tr class="stripe ">
# <td>
#                             </td>
# <td class="search-version--td">
# <div class="search-version--link js-tooltip">
# <a class="song result-link js-search-spelling-link" href="https://tabs.ultimate-guitar.com/j/justin_bieber/love_yourself_ver4_ukulele_crd.htm" onclick="window.trackCorrected('TAB')">
# <b>Love</b> <b>Yourself</b> (ver 4)                                                                            </a>
# <div class="tabinfo link-tooltip ">
#                                         info
#                                         <div class="link-tooltip--text dark js-tooltip-content">
#                                             Ukulele tab derived from the guitar part.                                        </div>
# </div>
# </div>
# <div class="dn" id="info_1934665">
# <font style="font-family:trebuchet ms;font-size:12px;font-weight:bold;line-height:120%"><b><font color="#DDDDCC">+</font> Difficulty:</b> <font color="#DDDDCC">novice</font><br/></font>
# </div>
# </td>
# <td class="gray4 tresults--rating"></td>
# <td><strong>ukulele</strong></td>
# </tr>
# </table>
# <div class="ads_footer">
# <table cellspacing="20" style="margin: -10px auto;">
# <tr class="js-ab-regular">
# <td>
# <script id="ad_cs_4219367_300_250">
#                                         window.gpads.que.push({cs: 'ad_cs_4219367_300_250', p: 4219367, w: 300, h: 250, q_str: '&subcat=search'});
#                                     </script>
# </td>
# <td>
# <script id="ad_cs_2010322_300_250">
#                                         window.gpads.que.push({cs: 'ad_cs_2010322_300_250', p: 2010322, w: 300, h: 250, q_str: '&subcat=search'});
#                                     </script>
# </td>
# </tr>
# </table>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <script type="text/javascript">
# window.addEventListener('load', function() {
#     $(".search_b_adv").removeClass("dn");
#
#
#     if($("#select1:visible").length == 1)
#     {
#         $("#search_bar_advanced .cus").addClass("searchbut");
#         $("SELECT").selectBox();
#         $('A.scroll-pane').jScrollPane({verticalDragMinHeight: 26, verticalDragMaxHeight:26, contentWidth: 86});
#     }
#
#     $("#expand_search_link").live("click", function(){
#         if ($("a.scroll-pane").length ==0)
#         {
#             $("#search_bar_advanced .cus").addClass("searchbut");
#             $("SELECT").selectBox();
#             $('A.scroll-pane').jScrollPane({verticalDragMinHeight: 26, verticalDragMaxHeight:26, contentWidth: 86});
#         }
#     });
#
#     $.getScript('//cdn.ustatik.com/js/jquery/jquery.cluetip.js', function(){
#
#         $('.tabinfo').cluetip(
#         {
#             local        : true,
#             cluetipClass : 'tabinfo',
#             activation   : 'hover',
#             showTitle    : false,
#             width        : 170
#         });
#
#     });
#     $.getScript('//cdn.ustatik.com/js/jquery/jquery.selectBox.js', function(){});
#     $.getScript('//cdn.ustatik.com/js/jquery/jquery.jscrollpane.min.js', function(){});
# });
# </script>
# <script async="" src="//cdn.ustatik.com/public/js/search_ver1492455806.js"></script>
# <script type="text/javascript">
#
#     window.addEventListener('load', function() {
#         $('.more').click(function()
#         {
#             if (!$(this).hasClass('hide'))
#             {
#                 $(this).parent().parent().find('.mor').slideDown(500);
#                 $(this).html('<b></b>hide').addClass('hide');
#             }
#             else
#             {
#                 $(this).parent().parent().find('.mor').slideUp(500);
#                 $(this).html('<b></b>more').removeClass('hide');
#             }
#
#             return false;
#         });
#     });
# </script>
# <script crossorigin="anonymous" src="//cdn.ustatik.com/public/js/performance/jinba_ver1492455806.js"></script>
# <script>
#     Jinba.config({
#         url:'https://track.ultimate-guitar.com/jinba.trc',
#         batchTimeout: 1000
#     });
#     var TAG_WEBSITE = {
#         app_label: 'search_page'
#     };
#
#
#     window.addEventListener('DOMContentLoaded', function() {
#
#         var jinbaRequest = new Jinba.Request(location.pathname, TAG_WEBSITE);
#         Jinba.MeasureNetworkTiming(jinbaRequest);
#         jinbaRequest.end();
#
#
#     });
# </script> <div class="footer_wrp">
# <script crossorigin="anonymous" src="//cdn.ustatik.com/js/jquery/jquery.min_ver2.js" type="text/javascript"></script>
# <!--FOOTER-->
# <div align="center" class="headtbl bord_lr_3">
# <table cellpadding="0" cellspacing="0" class="b foot bdrunion">
# <tr>
# <td class="bg2union" height="35" style="font-size:10px" width="100%">
# <b>
# <div class="pull-right ug-footer--social">
# <a class="ug-social-btn ug-social-btn__fb js-track-metrica-click" data-metrica-click="CLICK_SOCIAL_FACEBOOK" href="//www.facebook.com/UltimateGuitar" target="_blank"></a>
# <a class="ug-social-btn ug-social-btn__twitter js-track-metrica-click" data-metrica-click="CLICK_SOCIAL_TWITTER" href="//twitter.com/ultimateguitar" target="_blank"></a>
# <a class="ug-social-btn ug-social-btn__instagram js-track-metrica-click" data-metrica-click="CLICK_SOCIAL_INSTAGRAM" href="//www.instagram.com/ultimateguitar/" target="_blank"></a>
# </div>
# <span class="ug-footer--copy pull-right">© 2017 Ultimate-Guitar.com. All rights reserved  </span>
#                     <a class="ws1" href="https://www.ultimate-guitar.com/about/">About</a> |
#                     <a class="ws1" href="https://www.ultimate-guitar.com/article/blog">Blog</a> |
#                     <a class="ws1" href="https://www.ultimate-guitar.com/about/tos.htm">TOS</a> |
#                     <a class="ws1" href="https://www.ultimate-guitar.com/about/privacy.htm">Privacy</a> |
#                     <a class="ws1" href="https://www.ultimate-guitar.com/about/advertise.htm"><span style="color:#FFC600">Advertise</span></a> |
#                     <a class="ws1" href="https://www.ultimate-guitar.com/components/support/auth/redirect">Support</a>
# </b>
# </td>
# </tr>
# </table>
# <!--/FOOTER-->
# </div>
# <script type="text/javascript">
#     var artist_id = 0;
#     var name_art = '';
#
#     var main_server_name = 'ultimate-guitar.com';
#     var ps_serv = 'https://plus.ultimate-guitar.com';
# </script>
# <script type="text/javascript">
#
# // GA start
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-9160560-1', 'auto');
#
#
#
# ga('set', 'dimension5', 'https');
#
# var ga_client_id = null;
#
# ga(function(tracker) {
#     ga_client_id = tracker.get('clientId');
#     ga('set', 'dimension4', ga_client_id);
#
#     });
#
# ga('send', 'pageview');
# // GA end
#
# // Yandex.Metrika counter
# (function (d, w, c) {
#     (w[c] = w[c] || []).push(function() {
#         try {
#             w.yaCounter18746557 = new Ya.Metrika({id:18746557,
#                     webvisor:true,
#                     clickmap:true,
#                     trackLinks:true,
#                     triggerEvent:true,
#                     accurateTrackBounce:true});
#         } catch(e) { }
#     });
#
#     var n = d.getElementsByTagName("script")[0],
#         s = d.createElement("script"),
#         f = function () { n.parentNode.insertBefore(s, n); };
#     s.type = "text/javascript";
#     s.async = true;
#     s.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//mc.yandex.ru/metrika/watch.js";
#
#     if (w.opera == "[object Opera]") {
#         d.addEventListener("DOMContentLoaded", f, false);
#     } else { f(); }
# })(document, window, "yandex_metrika_callbacks");
# // Yandex.Metrika counter end
#
# </script>
# <!-- Yandex.Metrika counter -->
# <noscript><div><img alt="" src="//mc.yandex.ru/watch/18746557" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <script type="text/javascript">
# (function () {
#     var img = new Image();
#     img.src = '//www.ultimat' + 'e-guitar.com/app_event/?YES_SCRIPT&cb=35279812';
# })();
# </script>
# <noscript><div><img alt="" src="//www.ultimate-guitar.com/app_event/?NO_SCRIPT&amp;cb='35279812" style="position:absolute; left:-9998px;"/></div></noscript>
# <script crossorigin="anonymous" src="//cdn.ustatik.com/js/ug_scripts_ver1492455806.js"></script>
# <script src="//cdn.ustatik.com/public/js/classic_ver1492455806.js"></script>
# </div>
# </link></div>
# </center>
# </body>
# </html>
