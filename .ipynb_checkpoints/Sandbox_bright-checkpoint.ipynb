# %%
import bs4
import requests
import pandas

# %%
# Returns the Beautifulsoup of the input 'web_url'
def soup_page(web_url):
    req = requests.get(web_url)
    req_soup = bs4.BeautifulSoup(req.content, 'html.parser')
    return req_soup

# This function scrapes chords from a ultimate guitar website and
# returns a list of all the chords on that page
def get_chords(web_url):
    req_soup = soup_page(web_url)
    content = req_soup.find_all('pre', {'class':'js-tab-content'})
    chords_list = [word.replace('<span>', '').replace('</span>', '') for word in str(content).split() if word[0:6] == '<span>']
    return chords_list

# Check whether a certain query has any result on ultimate guitar
# return false if there is at least one result, true otherwise
def check_no_result(soup_result):
    not_found = soup_result.find_all('div',{'class':'not_found'})
    return len(not_found) != 0

# Returns the table of different versions from the search page
def get_table(soup_result):
    return soup_result.find_all('table', {'class':'tresults'})[0]

# Returns a list of rows
def get_rows(soup_result):
    return get_table(soup_result).find_all('tr')[1:len(get_table(soup_result))]

# Returns the rating of a certain row in the ultimate guitar result page
def get_rating(row):
    temp_rate = row.find('td', {'class':'gray4 tresults--rating'})
    rate_list = temp_rate.find_all('b', {'class':'ratdig'})
    if (len(rate_list) > 0):
        rate = rate_list[0].text.strip()
        return float(rate)

# Returns the type of a certain row in a result page
def get_type(row):
    row_type_list = row.find_all('strong')
    if (len(row_type_list) > 0):
        row_type = row_type_list[0].text.strip()
        return row_type

# Return the url of a certain row (version) of chords in a result page
def get_url(row):
    search_version = row.find_all('td',{'class':'search-version--td'})[0]
    href = search_version.find_all('a')[0].attrs['href']
    return href

# Gets the top 100 songs from Billboard of the input year
def get_top100(int_year):
    pairs = list()
    top100Songs = list()
    pairs = [data(d) for d in update_bbd_url(int_year)]
    for p in pairs:
        top100Songs += p
    return top100Songs

# Converts the top 100 songs in a particular year into
# a searchable string
def get_top100_query(int_year):
    if (int_year > 2016): int_year = 2016
    elif (int_year < 2006): int_year = 2006
    top100 = get_top100(int_year)
    result = [clean_pair(pair) for pair in top100]
    return result

# clean (artist, song title pair)
def clean_pair(pair):
    return clean_name(pair[0]) + ' ' + clean_name(pair[1])

# Clean up both artist name and song titles from get_top100() list
def clean_name(str_input):
    return str_input.lower().replace('(','').replace(')','').replace('&','').split('featuring',1)[0]

# Generates a search result page based on the input
# The url can be both a list of different versions of chords
# or "No Result" page
def search_url(str_query):
    root = 'https://www.ultimate-guitar.com/search.php?search_type=title&order=&value='
    str_query = str_query.replace(' ', '+')
    return root+str_query

# -- Puyush's functions --
def get_bbd_year_url(year_input):
    url = 'http://www.billboard.com/charts/year-end/'
    url += str(year_input)
    url += '/hot-100-songs'
    return url

def update_bbd_url(int_year):
    billboard = requests.get(get_bbd_year_url(int_year))
    billboard_soup = bs4.BeautifulSoup(billboard.content, 'html.parser')
    innerContent =  billboard_soup.find_all('div', {'data-content-type': 'yearEndChart'})
    artistData = innerContent[0].find_all('div' , {'class': 'ye-chart__layout-row'})
    artistData = artistData[1:]
    return artistData

def data(row):
    p = list()
    article = row.find_all('article', {'id': 'chart'})
    for i in range(len(article)):
        article_chart = article[i].find_all('div', {'class': 'ye-chart__item-primary'})
        songTitle = article_chart[0].find_all('h1', {'class':'ye-chart__item-title'})[0].text.strip()
        artistName = article_chart[0].find_all('h2', {'class':'ye-chart__item-subtitle'})[0].text.strip()
        p.append((artistName, songTitle))
    return p
# -- End of Puyush's functions --

# %%
query_list = get_top100_query(2015)

# %%
for query in query_list:
    search_result_url = search_url(query)
    search_result_soup = soup_page(search_result_url)
    if (not check_no_result(search_result_soup)):
        rows = get_rows(search_result_soup)
        max_rating = 0
        max_url = ""
        for row in rows:
            if get_type(row).lower() == 'chords' and get_rating(row) != None and get_rating(row) > max_rating:
                max_rating = get_rating(row)
                max_url = get_url(row)
        if (max_rating != 0):
            print(query, " ", max_rating)
            print(max_url)
# Out:
# mark ronson  uptown funk!   184.0
# https://tabs.ultimate-guitar.com/m/mark_ronson/uptown_funk_crd.htm
# ed sheeran thinking out loud   4826.0
# https://tabs.ultimate-guitar.com/e/ed_sheeran/thinking_out_loud_crd.htm
# wiz khalifa  see you again   836.0
# https://tabs.ultimate-guitar.com/w/wiz_khalifa/see_you_again_ver5_crd.htm
# fetty wap trap queen   134.0
# https://tabs.ultimate-guitar.com/f/fetty_wap/trap_queen_crd.htm
# maroon 5 sugar   330.0
# https://tabs.ultimate-guitar.com/m/maroon_5/sugar_ver3_crd.htm
# walk the moon shut up and dance   629.0
# https://tabs.ultimate-guitar.com/w/walk_the_moon/shut_up_and_dance_ver2_crd.htm
# taylor swift blank space   1071.0
# https://tabs.ultimate-guitar.com/t/taylor_swift/blank_space_crd.htm
# the weeknd the hills   208.0
# https://tabs.ultimate-guitar.com/t/the_weeknd/the_hills_ver2_crd.htm
# omi cheerleader   211.0
# https://tabs.ultimate-guitar.com/o/omi/cheerleader_ver2_crd.htm
# the weeknd can't feel my face   366.0
# https://tabs.ultimate-guitar.com/t/the_weeknd/cant_feel_my_face_crd.htm
# ellie goulding love me like you do   806.0
# https://tabs.ultimate-guitar.com/e/ellie_goulding/love_me_like_you_do_ver6_crd.htm
# hozier take me to church   1384.0
# https://tabs.ultimate-guitar.com/h/hozier/take_me_to_church_ver2_crd.htm
# taylor swift  bad blood   263.0
# https://tabs.ultimate-guitar.com/t/taylor_swift/bad_blood_crd.htm
# jason derulo want to want me   198.0
# https://tabs.ultimate-guitar.com/j/jason_derulo/want_to_want_me_crd.htm
# taylor swift shake it off   695.0
# https://tabs.ultimate-guitar.com/t/taylor_swift/shake_it_off_crd.htm
# rachel platten fight song   686.0
# https://tabs.ultimate-guitar.com/r/rachel_platten/fight_song_crd.htm
# fetty wap  679   92.0
# https://tabs.ultimate-guitar.com/f/fetty_wap/679_crd.htm
# meghan trainor lips are movin   196.0
# https://tabs.ultimate-guitar.com/m/meghan_trainor/lips_are_movin_crd.htm
# fifth harmony  worth it   26.0
# https://tabs.ultimate-guitar.com/f/fifth_harmony/worth_it_crd.htm
# omarion  post to be   11.0
# https://tabs.ultimate-guitar.com/o/omarion/post_to_be_crd.htm
# andy grammer honey, i'm good.   94.0
# https://tabs.ultimate-guitar.com/a/andy_grammer/honey_im_good_ver5_crd.htm
# sam smith i'm not the only one   2068.0
# https://tabs.ultimate-guitar.com/s/sam_smith/im_not_the_only_one_crd.htm
# selena gomez  good for you   132.0
# https://tabs.ultimate-guitar.com/s/selena_gomez/good_for_you_ver3_crd.htm
# meghan trainor all about that bass   347.0
# https://tabs.ultimate-guitar.com/m/meghan_trainor/all_about_that_bass_crd.htm
# taylor swift style   419.0
# https://tabs.ultimate-guitar.com/t/taylor_swift/style_ver2_crd.htm
# drake hotline bling   460.0
# https://tabs.ultimate-guitar.com/d/drake/hotline_bling_ver2_crd.htm
# david guetta  hey mama   24.0
# https://tabs.ultimate-guitar.com/d/david_guetta/hey_mama_crd.htm
# flo rida  g.d.f.r.   4.0
# https://tabs.ultimate-guitar.com/f/flo_rida/gdfr_crd.htm
# justin bieber what do you mean?   408.0
# https://tabs.ultimate-guitar.com/j/justin_bieber/what_do_you_mean_crd.htm
# ed sheeran photograph   5289.0
# https://tabs.ultimate-guitar.com/e/ed_sheeran/photograph_crd.htm
# adele hello   1031.0
# https://tabs.ultimate-guitar.com/a/adele/hello_ver3_crd.htm
# shawn mendes stitches   1307.0
# https://tabs.ultimate-guitar.com/s/shawn_mendes/stitches_ver2_crd.htm
# tove lo talking body   93.0
# https://tabs.ultimate-guitar.com/t/tove_lo/talking_body_crd.htm
# nick jonas jealous   134.0
# https://tabs.ultimate-guitar.com/n/nick_jonas/jealous_crd.htm
# pitbull  ne-yo time of our lives   5.0
# https://tabs.ultimate-guitar.com/p/pitbull/time_of_our_lives_crd.htm
# r. city  locked away   299.0
# https://tabs.ultimate-guitar.com/r/rock_city/locked_away_ver2_crd.htm
# natalie la rose  somebody   7.0
# https://tabs.ultimate-guitar.com/n/natalie_la_rose/somebody_crd.htm
# fall out boy centuries   390.0
# https://tabs.ultimate-guitar.com/f/fall_out_boy/centuries_ver2_crd.htm
# fetty wap  my way   13.0
# https://tabs.ultimate-guitar.com/f/fetty_wap/come_my_way_crd.htm
# sam hunt take your time   248.0
# https://tabs.ultimate-guitar.com/s/sam_hunt/take_your_time_crd.htm
# maroon 5 animals   251.0
# https://tabs.ultimate-guitar.com/m/maroon_5/animals_crd.htm
# rihanna b**** better have my money   9.0
# https://tabs.ultimate-guitar.com/r/rihanna/bitch_better_have_my_money_crd.htm
# sia elastic heart   426.0
# https://tabs.ultimate-guitar.com/s/sia/elastic_heart_acoustic_crd.htm
# demi lovato cool for the summer   49.0
# https://tabs.ultimate-guitar.com/d/demi_lovato/cool_for_the_summer_ver4_crd.htm
# x ambassadors renegades   801.0
# https://tabs.ultimate-guitar.com/x/x_ambassadors/renegades_crd.htm
# usher  i don't mind   4.0
# https://tabs.ultimate-guitar.com/u/usher/i_dont_mind_crd.htm
# ariana grande  the weeknd love me harder   184.0
# https://tabs.ultimate-guitar.com/a/ariana_grande/love_me_harder_ver2_crd.htm
# taylor swift wildest dreams   1285.0
# https://tabs.ultimate-guitar.com/t/taylor_swift/wildest_dreams_crd.htm
# sam smith stay with me   2356.0
# https://tabs.ultimate-guitar.com/s/sam_smith/stay_with_me_crd.htm
# dj snake  alunageorge you know you like it   13.0
# https://tabs.ultimate-guitar.com/a/alunageorge/you_know_you_like_it_crd.htm
# fall out boy uma thurman   144.0
# https://tabs.ultimate-guitar.com/f/fall_out_boy/uma_thurman_ver2_crd.htm
# selena gomez the heart wants what it wants   220.0
# https://tabs.ultimate-guitar.com/s/selena_gomez/the_heart_wants_what_it_wants_crd.htm
# little big town girl crush   710.0
# https://tabs.ultimate-guitar.com/l/little_big_town/girl_crush_crd.htm
# trey songz slow motion   6.0
# https://tabs.ultimate-guitar.com/t/trey_songz/slow_motion_crd.htm
# one direction drag me down   341.0
# https://tabs.ultimate-guitar.com/o/one_direction/drag_me_down_ver4_crd.htm
# ariana grande one last time   181.0
# https://tabs.ultimate-guitar.com/a/ariana_grande/one_last_time_ver4_crd.htm
# nick jonas chains   57.0
# https://tabs.ultimate-guitar.com/n/nick_jonas/chains_crd.htm
# vance joy riptide   5251.0
# https://tabs.ultimate-guitar.com/v/vance_joy/riptide_ver3_crd.htm
# jidenna  classic man   5.0
# https://tabs.ultimate-guitar.com/j/jidenna/classic_man_crd.htm
# elle king ex's  oh's   518.0
# https://tabs.ultimate-guitar.com/e/elle_king/exs_and_ohs_ver7_crd.htm
# meghan trainor dear future husband   264.0
# https://tabs.ultimate-guitar.com/m/meghan_trainor/dear_future_husband_crd.htm
# charlie puth  marvin gaye   405.0
# https://tabs.ultimate-guitar.com/c/charlie_puth/marvin_gaye_crd.htm
# meghan trainor  like i'm gonna lose you   1225.0
# https://tabs.ultimate-guitar.com/m/meghan_trainor/like_im_gonna_lose_you_crd.htm
# tove lo habits stay high   67.0
# https://tabs.ultimate-guitar.com/t/tove_lo/habits_stay_high_crd.htm
# sam smith lay me down   772.0
# https://tabs.ultimate-guitar.com/s/sam_smith/lay_me_down_ver3_crd.htm
# macklemore  ryan lewis  downtown   21.0
# https://tabs.ultimate-guitar.com/m/macklemore_ryan_lewis/downtown_crd.htm
# sam hunt house party   59.0
# https://tabs.ultimate-guitar.com/s/sam_hunt/house_party_crd.htm
# luke bryan kick the dust up   46.0
# https://tabs.ultimate-guitar.com/l/luke_bryan/kick_the_dust_up_crd.htm
# george ezra budapest   956.0
# https://tabs.ultimate-guitar.com/g/george_ezra/budapest_ver2_crd.htm
# sia chandelier   1583.0
# https://tabs.ultimate-guitar.com/s/sia/chandelier_ver3_crd.htm
# kelly clarkson heartbeat song   93.0
# https://tabs.ultimate-guitar.com/k/kelly_clarkson/heartbeat_song_crd.htm
# ed sheeran don't   355.0
# https://tabs.ultimate-guitar.com/e/ed_sheeran/dont_ver3_crd.htm
# ella henderson ghost   274.0
# https://tabs.ultimate-guitar.com/e/ella_henderson/ghost_crd.htm
# alessia cara here   273.0
# https://tabs.ultimate-guitar.com/a/alessia_cara/here_acoustic_crd.htm
# mr. probz waves   266.0
# https://tabs.ultimate-guitar.com/m/mr_probz/waves_ver2_crd.htm
# ne-yo  she knows   9.0
# https://tabs.ultimate-guitar.com/d/derek_and_the_dominos/nobody_knows_you_when_youre_down_and_out_crd.htm
# one direction night changes   1056.0
# https://tabs.ultimate-guitar.com/o/one_direction/night_changes_crd.htm
# drake back to back   9.0
# https://tabs.ultimate-guitar.com/d/drake_white/back_to_free_acoustic_crd.htm
# calvin harris  disciples how deep is your love   128.0
# https://tabs.ultimate-guitar.com/c/calvin_harris/how_deep_is_your_love_crd.htm
